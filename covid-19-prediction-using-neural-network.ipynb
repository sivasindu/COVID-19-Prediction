# %% [markdown]
# ## **Covid-19 prediction using Neural Network**

# %% [markdown]
# ## Abstract

# %% [markdown]
# This notebook is devoted to predicting the COVID-19 spread dynamics in the world using neural networks of different structures. We will see how to make predictions based on linear regression, back propagation  and long short-term memory neural networks

# %% [markdown]
# ## Introduction

# %% [markdown]
# Today there is a lot of open data about the spread of COVID-19 in the world. However, few tools are presented to predict  these processes.
#
# 3 different mathematical models for the forecast calculation will taken.
#
# To do this, the division of the DataSet into training and test sets will be demonstrated, normalize data and make preliminary analysis.
#
# It will be shown how to build models and DataSets for using 2 different neural networks.
#
# The next step is to compare the accuracy and adequacy of the obtained models.

# %% [markdown]
# ## Steps or Stages

# %% [markdown]
# It consists of four stages:
#
# *   Download and preliminary analysis of data
# *   Linear Regression
# *   Back Propagation NN
# *   Long Short-Term Memory - LSTM

# %% [markdown]
# In first stage we pre-prepare data for analysis:
#
# *   change the data types of columns
# *   rows filtering
# *   elimination of missing data
# *   DataSet transformation
# *   data normalization
#
# During the next steps, we will demonstrate 3 different models .

# %% [markdown]
# ## Prerequisites
#
# *   Python
# *   Pandas
# *   Statistics
# *   NumPy
# *   Matplotlib
# *   Keras
# *   Scikit-Learn

# %% [markdown]
# ## Objectives

# %% [markdown]
# ## Required libraries Importing

# %% [markdown]
# Some libraries should be imported .

# %%
import pandas as pd
import numpy as np

# %%
covid_word = pd.read_csv('../input/covidowid/owid-covid-data.csv')
covid_word
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 187796      ZWE    Africa     Zimbabwe  2022-05-15     249206.0        0.0
# 187797      ZWE    Africa     Zimbabwe  2022-05-16     249431.0      225.0
# 187798      ZWE    Africa     Zimbabwe  2022-05-17     249748.0      317.0
# 187799      ZWE    Africa     Zimbabwe  2022-05-18     250007.0      259.0
# 187800      ZWE    Africa     Zimbabwe  2022-05-19     250206.0      199.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 187796             122.000        5482.0         0.0                0.857
# 187797             127.857        5484.0         2.0                0.714
# 187798             158.000        5484.0         0.0                0.429
# 187799             195.000        5486.0         2.0                0.714
# 187800             180.429        5487.0         1.0                0.857
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 187796  ...             1.6          30.7                  36.791
# 187797  ...             1.6          30.7                  36.791
# 187798  ...             1.6          30.7                  36.791
# 187799  ...             1.6          30.7                  36.791
# 187800  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 187796                         1.7            61.49                    0.571
# 187797                         1.7            61.49                    0.571
# 187798                         1.7            61.49                    0.571
# 187799                         1.7            61.49                    0.571
# 187800                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 187796                                   NaN                          NaN
# 187797                                   NaN                          NaN
# 187798                                   NaN                          NaN
# 187799                                   NaN                          NaN
# 187800                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 187796               NaN                                      NaN
# 187797               NaN                                      NaN
# 187798               NaN                                      NaN
# 187799               NaN                                      NaN
# 187800               NaN                                      NaN
#
# [187801 rows x 67 columns]

# %% [markdown]
# Let's study our DataSet. As you can see, it consist of 159321 rows × 67 columns. There is some missing data are observed in the DataSet. We should be sure that Python recognized types of data correctly.

# %%
covid_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187801 entries, 0 to 187800
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    187801 non-null  object
#  1   continent                                   176870 non-null  object
#  2   location                                    187801 non-null  object
#  3   date                                        187801 non-null  object
#  4   total_cases                                 180399 non-null  float64
#  5   new_cases                                   180190 non-null  float64
#  6   new_cases_smoothed                          179016 non-null  float64
#  7   total_deaths                                162023 non-null  float64
#  8   new_deaths                                  162021 non-null  float64
#  9   new_deaths_smoothed                         160860 non-null  float64
#  10  total_cases_per_million                     179566 non-null  float64
#  11  new_cases_per_million                       179357 non-null  float64
#  12  new_cases_smoothed_per_million              178188 non-null  float64
#  13  total_deaths_per_million                    161203 non-null  float64
#  14  new_deaths_per_million                      161201 non-null  float64
#  15  new_deaths_smoothed_per_million             160045 non-null  float64
#  16  reproduction_rate                           140328 non-null  float64
#  17  icu_patients                                24355 non-null   float64
#  18  icu_patients_per_million                    24355 non-null   float64
#  19  hosp_patients                               25613 non-null   float64
#  20  hosp_patients_per_million                   25613 non-null   float64
#  21  weekly_icu_admissions                       6073 non-null    float64
#  22  weekly_icu_admissions_per_million           6073 non-null    float64
#  23  weekly_hosp_admissions                      12120 non-null   float64
#  24  weekly_hosp_admissions_per_million          12120 non-null   float64
#  25  total_tests                                 76651 non-null   float64
#  26  new_tests                                   73618 non-null   float64
#  27  total_tests_per_thousand                    76651 non-null   float64
#  28  new_tests_per_thousand                      73618 non-null   float64
#  29  new_tests_smoothed                          99087 non-null   float64
#  30  new_tests_smoothed_per_thousand             99087 non-null   float64
#  31  positive_rate                               91397 non-null   float64
#  32  tests_per_case                              89869 non-null   float64
#  33  tests_units                                 101893 non-null  object
#  34  total_vaccinations                          50985 non-null   float64
#  35  people_vaccinated                           48558 non-null   float64
#  36  people_fully_vaccinated                     46007 non-null   float64
#  37  total_boosters                              23182 non-null   float64
#  38  new_vaccinations                            41701 non-null   float64
#  39  new_vaccinations_smoothed                   100393 non-null  float64
#  40  total_vaccinations_per_hundred              50985 non-null   float64
#  41  people_vaccinated_per_hundred               48558 non-null   float64
#  42  people_fully_vaccinated_per_hundred         46007 non-null   float64
#  43  total_boosters_per_hundred                  23182 non-null   float64
#  44  new_vaccinations_smoothed_per_million       100393 non-null  float64
#  45  new_people_vaccinated_smoothed              99375 non-null   float64
#  46  new_people_vaccinated_smoothed_per_hundred  99375 non-null   float64
#  47  stringency_index                            146156 non-null  float64
#  48  population                                  186651 non-null  float64
#  49  population_density                          167345 non-null  float64
#  50  median_age                                  155139 non-null  float64
#  51  aged_65_older                               153494 non-null  float64
#  52  aged_70_older                               154325 non-null  float64
#  53  gdp_per_capita                              154268 non-null  float64
#  54  extreme_poverty                             100750 non-null  float64
#  55  cardiovasc_death_rate                       154794 non-null  float64
#  56  diabetes_prevalence                         162353 non-null  float64
#  57  female_smokers                              117078 non-null  float64
#  58  male_smokers                                115473 non-null  float64
#  59  handwashing_facilities                      76052 non-null   float64
#  60  hospital_beds_per_thousand                  137349 non-null  float64
#  61  life_expectancy                             175620 non-null  float64
#  62  human_development_index                     150786 non-null  float64
#  63  excess_mortality_cumulative_absolute        6460 non-null    float64
#  64  excess_mortality_cumulative                 6460 non-null    float64
#  65  excess_mortality                            6460 non-null    float64
#  66  excess_mortality_cumulative_per_million     6460 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 96.0+ MB

# %% [markdown]
# As you can see, 66 columns of COVID-19 data were recognized correctly (float64). First 4 columns and tests_units were recognized as objects. Let's investigate them:

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields]
# Out:
#        iso_code continent     location      tests_units
# 0           AFG      Asia  Afghanistan              NaN
# 1           AFG      Asia  Afghanistan              NaN
# 2           AFG      Asia  Afghanistan              NaN
# 3           AFG      Asia  Afghanistan              NaN
# 4           AFG      Asia  Afghanistan              NaN
# ...         ...       ...          ...              ...
# 187796      ZWE    Africa     Zimbabwe  tests performed
# 187797      ZWE    Africa     Zimbabwe  tests performed
# 187798      ZWE    Africa     Zimbabwe  tests performed
# 187799      ZWE    Africa     Zimbabwe  tests performed
# 187800      ZWE    Africa     Zimbabwe              NaN
#
# [187801 rows x 4 columns]

# %% [markdown]
# Let's show information about the field date.

# %%
covid_word['date']
# Out:
# 0         2020-02-24
# 1         2020-02-25
# 2         2020-02-26
# 3         2020-02-27
# 4         2020-02-28
#              ...
# 187796    2022-05-15
# 187797    2022-05-16
# 187798    2022-05-17
# 187799    2022-05-18
# 187800    2022-05-19
# Name: date, Length: 187801, dtype: object

# %% [markdown]
# ### Сhange the data types of columns

# %% [markdown]
# As you can see, the columns: 'iso_code', 'continent', 'location', 'tests_units' have many repetitions and should be assigned to categorical fields **pandas.astype()**.
#
# The field 'data' should be converted into DataTime type **pandas.to_datetime**
# To see the results we can use **pandas.describe()**.

# %%
fields = ['iso_code', 'continent', 'location', 'tests_units']
covid_word[fields] =covid_word[fields].astype('category')
covid_word.loc[:, 'date'] = pd.to_datetime(covid_word['date'])
covid_word[fields].describe()
# Out:
#        iso_code continent location      tests_units
# count    187801    176870   187801           101893
# unique      244         6      244                4
# top         ARG    Africa   Mexico  tests performed
# freq        870     43543      870            75951

# %% [markdown]
# ### Rows filtering

# %% [markdown]
# As we can see, the DataSet contains information about 6 continents and 238 countries.
# The field 'tests_units' consist of 4 categories. To show a list of countries, we can use **pandas.Series.cat.categories**.

# %%
covid_word['location'].cat.categories
# Out:
# Index(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=244)

# %% [markdown]
# Let's investigate the dynamics of new cases of COVID-19 for a separate country. We will use India for saving models and further forecast. You can use your country. Let's use a pandas filter to do this.

# %%
covid_word.index = covid_word['date']
c_covid = covid_word[covid_word['location'] == "India"]
c_covid
# Out:
#            iso_code continent location       date  total_cases  new_cases  \
# date
# 2020-01-30      IND      Asia    India 2020-01-30          1.0        1.0
# 2020-01-31      IND      Asia    India 2020-01-31          1.0        0.0
# 2020-02-01      IND      Asia    India 2020-02-01          1.0        0.0
# 2020-02-02      IND      Asia    India 2020-02-02          2.0        1.0
# 2020-02-03      IND      Asia    India 2020-02-03          3.0        1.0
# ...             ...       ...      ...        ...          ...        ...
# 2022-05-15      IND      Asia    India 2022-05-15   43123801.0     2202.0
# 2022-05-16      IND      Asia    India 2022-05-16   43125370.0     1569.0
# 2022-05-17      IND      Asia    India 2022-05-17   43127199.0     1829.0
# 2022-05-18      IND      Asia    India 2022-05-18   43129563.0     2364.0
# 2022-05-19      IND      Asia    India 2022-05-19   43131822.0     2259.0
#
#             new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# date
# 2020-01-30                 NaN           NaN         NaN                  NaN
# 2020-01-31                 NaN           NaN         NaN                  NaN
# 2020-02-01                 NaN           NaN         NaN                  NaN
# 2020-02-02                 NaN           NaN         NaN                  NaN
# 2020-02-03                 NaN           NaN         NaN                  NaN
# ...                        ...           ...         ...                  ...
# 2022-05-15            2628.571      524241.0        27.0               21.143
# 2022-05-16            2525.857      524260.0        19.0               22.429
# 2022-05-17            2373.286      524293.0        33.0               19.429
# 2022-05-18            2307.143      524303.0        10.0               17.429
# 2022-05-19            2224.000      524323.0        20.0               19.000
#
#             ...  female_smokers  male_smokers  handwashing_facilities  \
# date        ...
# 2020-01-30  ...             1.9          20.6                   59.55
# 2020-01-31  ...             1.9          20.6                   59.55
# 2020-02-01  ...             1.9          20.6                   59.55
# 2020-02-02  ...             1.9          20.6                   59.55
# 2020-02-03  ...             1.9          20.6                   59.55
# ...         ...             ...           ...                     ...
# 2022-05-15  ...             1.9          20.6                   59.55
# 2022-05-16  ...             1.9          20.6                   59.55
# 2022-05-17  ...             1.9          20.6                   59.55
# 2022-05-18  ...             1.9          20.6                   59.55
# 2022-05-19  ...             1.9          20.6                   59.55
#
#             hospital_beds_per_thousand  life_expectancy  \
# date
# 2020-01-30                        0.53            69.66
# 2020-01-31                        0.53            69.66
# 2020-02-01                        0.53            69.66
# 2020-02-02                        0.53            69.66
# 2020-02-03                        0.53            69.66
# ...                                ...              ...
# 2022-05-15                        0.53            69.66
# 2022-05-16                        0.53            69.66
# 2022-05-17                        0.53            69.66
# 2022-05-18                        0.53            69.66
# 2022-05-19                        0.53            69.66
#
#             human_development_index  excess_mortality_cumulative_absolute  \
# date
# 2020-01-30                    0.645                                   NaN
# 2020-01-31                    0.645                                   NaN
# 2020-02-01                    0.645                                   NaN
# 2020-02-02                    0.645                                   NaN
# 2020-02-03                    0.645                                   NaN
# ...                             ...                                   ...
# 2022-05-15                    0.645                                   NaN
# 2022-05-16                    0.645                                   NaN
# 2022-05-17                    0.645                                   NaN
# 2022-05-18                    0.645                                   NaN
# 2022-05-19                    0.645                                   NaN
#
#             excess_mortality_cumulative  excess_mortality  \
# date
# 2020-01-30                          NaN               NaN
# 2020-01-31                          NaN               NaN
# 2020-02-01                          NaN               NaN
# 2020-02-02                          NaN               NaN
# 2020-02-03                          NaN               NaN
# ...                                 ...               ...
# 2022-05-15                          NaN               NaN
# 2022-05-16                          NaN               NaN
# 2022-05-17                          NaN               NaN
# 2022-05-18                          NaN               NaN
# 2022-05-19                          NaN               NaN
#
#             excess_mortality_cumulative_per_million
# date
# 2020-01-30                                      NaN
# 2020-01-31                                      NaN
# 2020-02-01                                      NaN
# 2020-02-02                                      NaN
# 2020-02-03                                      NaN
# ...                                             ...
# 2022-05-15                                      NaN
# 2022-05-16                                      NaN
# 2022-05-17                                      NaN
# 2022-05-18                                      NaN
# 2022-05-19                                      NaN
#
# [841 rows x 67 columns]

# %% [markdown]
# Let's choose the fields 'new_cases', 'new_cases_smoothed' for forecasting. First of all, we should visualize this data.

# %%
import matplotlib.pyplot as plt
fields = ['new_cases', 'new_cases_smoothed']
c_covid[fields].plot()
plt.show()

# %% [markdown]
# ### Elimination of missing data

# %% [markdown]
# As you can see, there are large fluctuations in the new cases plot. Let's try to make a forecast for these waves.
# First of all, we should delete missing data using **pandas.DataFrame.dropna()**

# %%
c_covid = c_covid[fields].dropna()
c_covid
# Out:
#             new_cases  new_cases_smoothed
# date
# 2020-02-04        0.0               0.429
# 2020-02-05        0.0               0.429
# 2020-02-06        0.0               0.286
# 2020-02-07        0.0               0.286
# 2020-02-08        0.0               0.286
# ...               ...                 ...
# 2022-05-15     2202.0            2628.571
# 2022-05-16     1569.0            2525.857
# 2022-05-17     1829.0            2373.286
# 2022-05-18     2364.0            2307.143
# 2022-05-19     2259.0            2224.000
#
# [836 rows x 2 columns]

# %% [markdown]
# ### Data transformation

# %% [markdown]
#  To check for dependencies, it is necessary to perform a correlation analysis between them. This requires:
#
# 1.  duplicating of data and moving it vertically down for a certain number of days (lag)
# 2.  deleting the missing data at the beginning and end **pandas.DataFrame.shift()**
# 3.  calculating the correlation coefficient between the obtained series.
#
# It is convenient to create a separate function for lag:

# %%
def lag_correlation_ts(y, x, lag):
    """
   
    y: fixed
    x: shifted
    lag: lag for shifting
    r: DataFrame of lags correlation coefficients
    """
    r = [0] * (lag + 1)
    y = y.copy()
    x = x.copy()
    y.name = "y"
    x.name = "x"

    for i in range(0, lag + 1):
        ds = y.copy().to_frame()
        ds = ds.join(x.shift(i), how='outer')
        r[i] = ds.corr().values[0][1]
    r = pd.DataFrame(r)
    r.index.names = ['Lag']
    r.columns = ['Correlation']
    return r

# %% [markdown]
# Let's create a target DataSet.

# %%
y_dataset = c_covid['new_cases']
y_dataset
# Out:
# date
# 2020-02-04       0.0
# 2020-02-05       0.0
# 2020-02-06       0.0
# 2020-02-07       0.0
# 2020-02-08       0.0
#                ...
# 2022-05-15    2202.0
# 2022-05-16    1569.0
# 2022-05-17    1829.0
# 2022-05-18    2364.0
# 2022-05-19    2259.0
# Name: new_cases, Length: 836, dtype: float64

# %% [markdown]
# Let's test a 50-day lag.

# %%
pd.options.display.float_format = '{:,.4f}'.format
l = pd.DataFrame(lag_correlation_ts(y_dataset, y_dataset, 50)) 
print(l)
l.plot()
# Out:
#      Correlation
# Lag
# 0         1.0000
# 1         0.9947
# 2         0.9867
# 3         0.9783
# 4         0.9680
# 5         0.9562
# 6         0.9440
# 7         0.9289
# 8         0.9065
# 9         0.8820
# 10        0.8580
# 11        0.8334
# 12        0.8080
# 13        0.7834
# 14        0.7566
# 15        0.7248
# 16        0.6928
# 17        0.6625
# 18        0.6325
# 19        0.6030
# 20        0.5753
# 21        0.5471
# 22        0.5156
# 23        0.4851
# 24        0.4572
# 25        0.4302
# 26        0.4044
# 27        0.3805
# 28        0.3567
# 29        0.3309
# 30        0.3062
# 31        0.2839
# 32        0.2625
# 33        0.2422
# 34        0.2235
# 35        0.2051
# 36        0.1847
# 37        0.1656
# 38        0.1484
# 39        0.1318
# 40        0.1162
# 41        0.1023
# 42        0.0884
# 43        0.0728
# 44        0.0583
# 45        0.0453
# 46        0.0330
# 47        0.0212
# 48        0.0110
# 49        0.0008
# 50       -0.0110
# <AxesSubplot:xlabel='Lag'>

# %% [markdown]
# To automate this process, let's make a universal function for time series transformation to create this DataSet.

# %%
def series_to_supervised(in_data, tar_data, n_in=1, dropnan=True, target_dep=False):

    n_vars = in_data.shape[1]
    cols, names = list(), list()

    if target_dep:
        i_start = 1
    else:
        i_start = 0
    for i in range(i_start, n_in + 1):
        cols.append(in_data.shift(i))
        names += [('%s(t-%d)' % (in_data.columns[j], i)) for j in range(n_vars)]

    if target_dep:
        for i in range(n_in, -1, -1):
            cols.append(tar_data.shift(i))
            names += [('%s(t-%d)' % (tar_data.name, i))]
    else:
        # put it all together
        cols.append(tar_data)
        names.append(tar_data.name)
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %% [markdown]
#  When forecasting time series, the input and output fields are the same, only shifted by the lag.

# %%
dataset = series_to_supervised(pd.DataFrame(y_dataset), y_dataset, 14)
dataset
# Out:
#             new_cases(t-0)  new_cases(t-1)  new_cases(t-2)  new_cases(t-3)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-05-15      2,202.0000      2,487.0000      2,858.0000      2,841.0000
# 2022-05-16      1,569.0000      2,202.0000      2,487.0000      2,858.0000
# 2022-05-17      1,829.0000      1,569.0000      2,202.0000      2,487.0000
# 2022-05-18      2,364.0000      1,829.0000      1,569.0000      2,202.0000
# 2022-05-19      2,259.0000      2,364.0000      1,829.0000      1,569.0000
#
#             new_cases(t-4)  new_cases(t-5)  new_cases(t-6)  new_cases(t-7)  \
# date
# 2020-02-18          0.0000          0.0000          0.0000          0.0000
# 2020-02-19          0.0000          0.0000          0.0000          0.0000
# 2020-02-20          0.0000          0.0000          0.0000          0.0000
# 2020-02-21          0.0000          0.0000          0.0000          0.0000
# 2020-02-22          0.0000          0.0000          0.0000          0.0000
# ...                    ...             ...             ...             ...
# 2022-05-15      2,827.0000      2,897.0000      2,288.0000      3,207.0000
# 2022-05-16      2,841.0000      2,827.0000      2,897.0000      2,288.0000
# 2022-05-17      2,858.0000      2,841.0000      2,827.0000      2,897.0000
# 2022-05-18      2,487.0000      2,858.0000      2,841.0000      2,827.0000
# 2022-05-19      2,202.0000      2,487.0000      2,858.0000      2,841.0000
#
#             new_cases(t-8)  new_cases(t-9)  new_cases(t-10)  new_cases(t-11)  \
# date
# 2020-02-18          0.0000          0.0000           0.0000           0.0000
# 2020-02-19          0.0000          0.0000           0.0000           0.0000
# 2020-02-20          0.0000          0.0000           0.0000           0.0000
# 2020-02-21          0.0000          0.0000           0.0000           0.0000
# 2020-02-22          0.0000          0.0000           0.0000           0.0000
# ...                    ...             ...              ...              ...
# 2022-05-15      3,451.0000      3,805.0000       3,545.0000       3,275.0000
# 2022-05-16      3,207.0000      3,451.0000       3,805.0000       3,545.0000
# 2022-05-17      2,288.0000      3,207.0000       3,451.0000       3,805.0000
# 2022-05-18      2,897.0000      2,288.0000       3,207.0000       3,451.0000
# 2022-05-19      2,827.0000      2,897.0000       2,288.0000       3,207.0000
#
#             new_cases(t-12)  new_cases(t-13)  new_cases(t-14)  new_cases
# date
# 2020-02-18           0.0000           0.0000           0.0000     0.0000
# 2020-02-19           0.0000           0.0000           0.0000     0.0000
# 2020-02-20           0.0000           0.0000           0.0000     0.0000
# 2020-02-21           0.0000           0.0000           0.0000     0.0000
# 2020-02-22           0.0000           0.0000           0.0000     0.0000
# ...                     ...              ...              ...        ...
# 2022-05-15       3,205.0000       2,568.0000       3,157.0000 2,202.0000
# 2022-05-16       3,275.0000       3,205.0000       2,568.0000 1,569.0000
# 2022-05-17       3,545.0000       3,275.0000       3,205.0000 1,829.0000
# 2022-05-18       3,805.0000       3,545.0000       3,275.0000 2,364.0000
# 2022-05-19       3,451.0000       3,805.0000       3,545.0000 2,259.0000
#
# [822 rows x 16 columns]

# %% [markdown]
# As you can see, the first and last columns contain the same target data.
# Now we should create input (**X**) and output (**Y**) .

# %%
col = dataset.columns
X, Y = dataset[col[1:-1]], dataset[col[-1]]
print("Input: ", X.columns)
print("Target:", Y.name)
# Out:
# Input:  Index(['new_cases(t-1)', 'new_cases(t-2)', 'new_cases(t-3)', 'new_cases(t-4)',
#        'new_cases(t-5)', 'new_cases(t-6)', 'new_cases(t-7)', 'new_cases(t-8)',
#        'new_cases(t-9)', 'new_cases(t-10)', 'new_cases(t-11)',
#        'new_cases(t-12)', 'new_cases(t-13)', 'new_cases(t-14)'],
#       dtype='object')
# Target: new_cases

# %% [markdown]
# ### Data normalization

# %% [markdown]
# After that, we should normalize all the data. To do this, the **sklearn.preprocessing.MinMaxScaler** module should be used.
# It allows us to normalize **fit_transform()** and convert back all the data easily: **inverse_transform()**.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

scaled_x = scaler_x.fit_transform(X)
scaled_y = scaler_y.fit_transform(Y.values.reshape(-1, 1))

# %% [markdown]
# After that, we are going to form training and test DataSets using **sklearn.model_selection.train_test_split()**.
#
# We will make them at the ratio of 73/27. Without shuffling. It means, that test samples are located in the end of **X** and **Y** DataSets.
#
# Input normalized DataSets: **X_train, X_test**
#
# Target normalized DataSets: **y_train, y_test**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_x, scaled_y, test_size=0.32, shuffle=False)

# %% [markdown]
# All the data is normalized now. However, in order to compare to results, we need real scale data of the training and test DataSet:

# %%
res_train = scaler_y.inverse_transform(y_train).flatten()
res_test = scaler_y.inverse_transform(y_test).flatten()

# %% [markdown]
# Target real scale DataSets: **res_train, res_test**.

# %% [markdown]
# # Linear Regression

# %% [markdown]
# First of all, we should create a model. We will test three type of models. A Linear regression, a Multilayer Neural Network with Backpropagation and a Long Short-Term Memory Neural Network.
# Let's create a **LinearRegression()**

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %% [markdown]
# After that, our model should be fitted on the training DataSet. Regardless of the model type, the function fit() is used to do this.

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Then we can test it on the test DataSet and use it for prognostication.

# %%
y_pred_test_ln = regressor.predict(X_test)
y_pred_test_ln = scaler_y.inverse_transform(y_pred_test_ln).flatten()

# %% [markdown]
# Let's analyze the results accuracy using **sklearn.metrics**.

# %%
from sklearn import metrics
print("Correlation train", regressor.score(X_train, y_train))
print("Correlation test", regressor.score(X_test, y_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_test_ln))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_test_ln))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_test_ln)))
# Out:
# Correlation train 0.9966993360861955
# Correlation test 0.9887010809896141
# Mean Absolute Error: 39825.00426717726
# Mean Squared Error: 7272313854.298441
# Root Mean Squared Error: 85277.8626274043

# %% [markdown]
# # Back Propagation NN

# %% [markdown]
# The modern approach to the establishment of complex functional dependencies is the use of neural networks. A classical neural network is a **multilayer neural network with back propagation**.
#
# To do this, we will use the **keras** framework.
# First of all, we should create a Neural Network model as a separate function.
#
# A neural network is a sequence of layers. The function **Sequential()** is used to create a network.
#
# Let's create a network that consists of 2 hidden layers. Each of which consists of 100 neurons. **keras.layers.Dense()**.
#
# To avoid retraining problems, we will use additional layers **keras.layers.Dropout()**.
#
# The output layer will consist of one neuron, since we have only one value at the output.
#
# The model should be compiled for fitting and predicting: **keras.Model.compile()**.

# %%
def BP_model(X):
    """
    Multilayer neural network with back propagation.
    X: Input DataSet
    return: keras NN model
    """
    # create model
    model = Sequential() 
    model.add(Dense(100, input_dim=X.shape[1], kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, kernel_initializer='normal', activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, kernel_initializer='normal'))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %% [markdown]
# Once the model function is built, it is necessary to create a neural network directly and specify the learning parameters: **keras.wrappers.scikit_learn.KerasRegressor()**.
#
# Also we should define the number of fitting **epoch and batch size**.

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
epochs = 1000

batch_size=int(y_train.shape[0]*.1)

estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)

# %% [markdown]
# Now, let’s train our model for **1000** epochs.
# It should be noted that the fitting process is very slow. Therefore, we saved our fitted model to a file.
# To save time, we will upload the fitted model.
# If you like, you can leave the parameter **fitting on True** to refit the model.
# If you like, you can leave the parameter **fitting_save on True** to resave the model.

# %%
fitting = True
fitting_save = True

import pickle

if fitting:
    history=estimator.fit(X_train,y_train, validation_data=(X_test,y_test)) # Fitting model
    if fitting_save:
        # Save model
        estimator.model.save('BP_saved_model.h5')
        print("Saved model to disk")
        with open('history.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model 
from keras.models import load_model
estimator = KerasRegressor(build_fn=BP_model, X=X_train, epochs=epochs, batch_size=batch_size, verbose=1)
estimator.model = load_model('BP_saved_model.h5')    
with open('history.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# User settings:
#
#    KMP_AFFINITY=granularity=fine,noverbose,compact,1,0
#    KMP_BLOCKTIME=0
#    KMP_DUPLICATE_LIB_OK=True
#    KMP_INIT_AT_FORK=FALSE
#    KMP_SETTINGS=1
#    KMP_WARNINGS=0
#
# Effective settings:
#
#    KMP_ABORT_DELAY=0
#    KMP_ADAPTIVE_LOCK_PROPS='1,1024'
#    KMP_ALIGN_ALLOC=64
#    KMP_ALL_THREADPRIVATE=128
#    KMP_ATOMIC_MODE=2
#    KMP_BLOCKTIME=0
#    KMP_CPUINFO_FILE: value is not defined
#    KMP_DETERMINISTIC_REDUCTION=false
#    KMP_DEVICE_THREAD_LIMIT=2147483647
#    KMP_DISP_NUM_BUFFERS=7
#    KMP_DUPLICATE_LIB_OK=true
#    KMP_ENABLE_TASK_THROTTLING=true
#    KMP_FORCE_REDUCTION: value is not defined
#    KMP_FOREIGN_THREADS_THREADPRIVATE=true
#    KMP_FORKJOIN_BARRIER='2,2'
#    KMP_FORKJOIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_GTID_MODE=3
#    KMP_HANDLE_SIGNALS=false
#    KMP_HOT_TEAMS_MAX_LEVEL=1
#    KMP_HOT_TEAMS_MODE=0
#    KMP_INIT_AT_FORK=true
#    KMP_LIBRARY=throughput
#    KMP_LOCK_KIND=queuing
#    KMP_MALLOC_POOL_INCR=1M
#    KMP_NUM_LOCKS_IN_BLOCK=1
#    KMP_PLAIN_BARRIER='2,2'
#    KMP_PLAIN_BARRIER_PATTERN='hyper,hyper'
#    KMP_REDUCTION_BARRIER='1,1'
#    KMP_REDUCTION_BARRIER_PATTERN='hyper,hyper'
#    KMP_SCHEDULE='static,balanced;guided,iterative'
#    KMP_SETTINGS=true
#    KMP_SPIN_BACKOFF_PARAMS='4096,100'
#    KMP_STACKOFFSET=64
#    KMP_STACKPAD=0
#    KMP_STACKSIZE=8M
#    KMP_STORAGE_MAP=false
#    KMP_TASKING=2
#    KMP_TASKLOOP_MIN_TASKS=0
#    KMP_TASK_STEALING_CONSTRAINT=1
#    KMP_TEAMS_THREAD_LIMIT=4
#    KMP_TOPOLOGY_METHOD=all
#    KMP_USE_YIELD=1
#    KMP_VERSION=false
#    KMP_WARNINGS=false
#    OMP_AFFINITY_FORMAT='OMP: pid %P tid %i thread %n bound to OS proc set {%A}'
#    OMP_ALLOCATOR=omp_default_mem_alloc
#    OMP_CANCELLATION=false
#    OMP_DEFAULT_DEVICE=0
#    OMP_DISPLAY_AFFINITY=false
#    OMP_DISPLAY_ENV=false
#    OMP_DYNAMIC=false
#    OMP_MAX_ACTIVE_LEVELS=1
#    OMP_MAX_TASK_PRIORITY=0
#    OMP_NESTED: deprecated; max-active-levels-var=1
#    OMP_NUM_THREADS: value is not defined
#    OMP_PLACES: value is not defined
#    OMP_PROC_BIND='intel'
#    OMP_SCHEDULE='static'
#    OMP_STACKSIZE=8M
#    OMP_TARGET_OFFLOAD=DEFAULT
#    OMP_THREAD_LIMIT=2147483647
#    OMP_WAIT_POLICY=PASSIVE
#    KMP_AFFINITY='noverbose,warnings,respect,granularity=fine,compact,1,0'
# Epoch 1/1000
# 11/11 [==============================] - 1s 26ms/step - loss: 0.0436 - val_loss: 0.0169
# Epoch 2/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0103 - val_loss: 0.0143
# Epoch 3/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 4/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0069
# Epoch 5/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0054
# Epoch 6/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0031 - val_loss: 0.0048
# Epoch 7/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0036
# Epoch 8/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 9/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 10/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 11/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 12/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 13/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 14/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 15/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 16/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 17/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 18/1000
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 20/1000
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 21/1000
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 22/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 23/1000
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 24/1000
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 25/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 26/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 27/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 28/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 29/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 30/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3161e-04 - val_loss: 0.0011
# Epoch 31/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.1662e-04 - val_loss: 0.0013
# Epoch 32/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 9.0249e-04
# Epoch 33/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 34/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 8.8983e-04
# Epoch 35/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 36/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 37/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 38/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 39/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 40/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 9.3242e-04
# Epoch 41/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 42/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 43/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9
1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.9029e-04 - val_loss: 5.6876e-04
# Epoch 376/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3697e-04 - val_loss: 9.0045e-04
# Epoch 377/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 5.7705e-04 - val_loss: 0.0011
# Epoch 378/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 8.7214e-04 - val_loss: 7.9144e-04
# Epoch 379/1000
# 11/11 [==============================] - 0s 16ms/step - loss: 7.7332e-04 - val_loss: 5.5572e-04
# Epoch 380/1000
# 11/11 [==============================] - 0s 11ms/step - loss: 6.6215e-04 - val_loss: 5.3958e-04
# Epoch 381/1000
# 11/11 [==============================] - 0s 22ms/step - loss: 8.5622e-04 - val_loss: 8.5361e-04
# Epoch 382/1000
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 383/1000
# 11/11 [==============================] - 0s 19ms/step - loss: 8.5467e-04 - val_loss: 8.3022e-04
# Epoch 384/1000
# 11/11 [==============================] - 0s 15ms/step - loss: 8.6715e-04 - val_loss: 6.8823e-04
# Epoch 385/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.9577e-04 - val_loss: 7.6228e-04
# Epoch 386/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.4578e-04 - val_loss: 8.5682e-04
# Epoch 387/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.7034e-04 - val_loss: 0.0011
# Epoch 388/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.4284e-04 - val_loss: 7.1866e-04
# Epoch 389/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.3668e-04 - val_loss: 7.5504e-04
# Epoch 390/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.6448e-04 - val_loss: 8.9404e-04
# Epoch 391/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.6114e-04 - val_loss: 0.0011
# Epoch 392/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.6628e-04 - val_loss: 5.0358e-04
# Epoch 393/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9214e-04 - val_loss: 9.2723e-04
# Epoch 394/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5898e-04 - val_loss: 8.4077e-04
# Epoch 395/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3654e-04 - val_loss: 0.0011
# Epoch 396/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7411e-04 - val_loss: 6.0151e-04
# Epoch 397/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 5.8334e-04 - val_loss: 8.1315e-04
# Epoch 398/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 5.7425e-04 - val_loss: 0.0012
# Epoch 399/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9618e-04 - val_loss: 5.6968e-04
# Epoch 400/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 8.8830e-04
# Epoch 401/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.8311e-04 - val_loss: 8.5671e-04
# Epoch 402/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 7.6336e-04 - val_loss: 7.8773e-04
# Epoch 403/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 8.2470e-04 - val_loss: 8.6600e-04
# Epoch 404/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 7.0638e-04 - val_loss: 0.0011
# Epoch 405/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.7161e-04 - val_loss: 8.2520e-04
# Epoch 406/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 6.9697e-04 - val_loss: 0.0013
# Epoch 407/1000
# 11/11 [==============================] - 0s 7ms/step - loss: 6.5561e-04 - val_loss: 7.1008e-04
# Epoch 408/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.4653e-04 - val_loss: 6.2002e-04
# Epoch 409/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 5.8734e-04 - val_loss: 0.0014
# Epoch 410/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 5.2561e-04
# Epoch 411/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 9.2718e-04 - val_loss: 8.8998e-04
# Epoch 412/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 6.5651e-04 - val_loss: 0.0011
# Epoch 413/1000
# 11/11 [==============================] - 0s 11ms/step - loss: 4.9824e-04 - val_loss: 5.8384e-04
# Epoch 414/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 8.7544e-04 - val_loss: 8.9154e-04
# Epoch 415/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 6.4345e-04 - val_loss: 0.0011
# Epoch 416/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 5.0409e-04 - val_loss: 6.3102e-04
# Epoch 417/1000
# 11/11 [==============================] - 0s 8ms/step - loss: 5.7820e-04 - val_loss: 0.0013
# Epoch 418/1000
# 11/11 [==============================] - 0s 9ms/step - loss: 8.2768e-04 - val_loss: 6.2049e-04
# Epoch 419/1000
# 11/11 [==============================] - 0s 10ms/step - loss: 4.3712e-04 - val_loss: 8.3594e-04
# Epoch 420/1000
# 11/11 [==============================] - 0s 9ms/step - loss:
1000
# 11/11 [==============================] - 0s 12ms/step - loss: 6.6289e-04 - val_loss: 0.0013
# Saved model to disk
# Loaded model from disk

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# As you can see, a Neural Network is well-fitted and no overfitting is observed.
# Let's calculate a prediction of the training (**res_train_ANN**) an test (**res_test_ANN**) sets.

# %% [markdown]
# Let's calculate a forecast and make an inverse normalization to real scale.

# %%
res_tr=estimator.predict(X_train)
res_ts=estimator.predict(X_test)
res_train_ANN=scaler_y.inverse_transform(res_tr.reshape(-1, 1)).flatten()
res_test_ANN=scaler_y.inverse_transform(res_ts.reshape(-1, 1)).flatten()
# Out:
# 11/11 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# Let's compare the accuracy of a Linear Regression and a Neural Network.

# %%
print("Correlation train", np.corrcoef(res_train, res_train_ANN)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_ANN)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_ANN))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_ANN))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_ANN)))
# Out:
# Correlation train 0.9981953760073724
# Correlation train 0.9913278887624895
# Mean Absolute Error: 42140.91734954225
# Mean Squared Error: 8211490988.947639
# Root Mean Squared Error: 90617.27754102768

# %% [markdown]
# We got slightly better results for a Neural Network than for a Linear Regression.

# %% [markdown]
# # Long Short-Term Memory - LSTM

# %% [markdown]
# Unlike standard feedforward neural networks, **LSTM** has feedback connections. It can process not only single data points, but also entire sequences of data (such as speech, video or time series).
#
# In case of time series, the neural network has one input and one output. However, there should be a vector of time series values for the previous time period on the input.

# %% [markdown]
# To do this, we should transform input DataSets into 3D shape.

# %%
train_x_LSTM = X_train.reshape((X_train.shape[0], 1, 14))
test_x_LSTM = X_test.reshape((X_test.shape[0], 1, 14))

# %% [markdown]
# Let's create an LSTM Neural Network consisting of one **LSTM** layer and one BP layer like in the previous case.
# In this case our NN will consist of 7 LSTM and 7 BP neurons only.

# %%
from keras.layers import LSTM

batch_size=int(y_train.shape[0]*.1)
model = Sequential()
model.add(LSTM(7, input_shape=(train_x_LSTM.shape[1], train_x_LSTM.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(7, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1])) #activation='sigmoid'
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# All subsequent steps of learning, storing, reading and predicting are similar to the ones we used with the previous neural network. You can see that only 420 epochs are enough for an LSTM.

# %%
fitting = True
fitting_save = True
epochs = 420

if fitting:
    history = model.fit(train_x_LSTM, y_train, epochs=epochs, batch_size=batch_size, validation_data=(test_x_LSTM, y_test), verbose=1, shuffle=False)    
    if fitting_save:
    # serialize model to JSON
        model_json = model.to_json()
        with open("LSTM_model.json", "w") as json_file:
            json_file.write(model_json)
        # serialize weights to HDF5
        model.save_weights("LSTM_model.h5")
        print("Saved model to disk")
        with open('history_LSTM.pickle', 'wb') as f:
            pickle.dump(history.history, f)
# load model  
from keras.models import model_from_json
json_file = open('LSTM_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("LSTM_model.h5")        
with open('history_LSTM.pickle', 'rb') as f:
    history = pickle.load(f)
print("Loaded model from disk")
# Out:
# Epoch 1/420
# 11/11 [==============================] - 3s 62ms/step - loss: 0.0514 - val_loss: 0.0337
# Epoch 2/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0435 - val_loss: 0.0303
# Epoch 3/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0389 - val_loss: 0.0281
# Epoch 4/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0347 - val_loss: 0.0267
# Epoch 5/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0329 - val_loss: 0.0256
# Epoch 6/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0316 - val_loss: 0.0246
# Epoch 7/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0265 - val_loss: 0.0234
# Epoch 8/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0261 - val_loss: 0.0220
# Epoch 9/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0254 - val_loss: 0.0205
# Epoch 10/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0224 - val_loss: 0.0189
# Epoch 11/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0184 - val_loss: 0.0172
# Epoch 12/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0179 - val_loss: 0.0156
# Epoch 13/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0142
# Epoch 14/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0129
# Epoch 15/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0116 - val_loss: 0.0119
# Epoch 16/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 17/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0094 - val_loss: 0.0106
# Epoch 18/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0116 - val_loss: 0.0101
# Epoch 19/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0088 - val_loss: 0.0098
# Epoch 20/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0097
# Epoch 21/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0095
# Epoch 22/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0094
# Epoch 23/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 0.0093
# Epoch 24/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 25/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 26/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 27/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 28/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 29/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 30/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0087
# Epoch 31/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0106 - val_loss: 0.0086
# Epoch 32/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 33/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0076 - val_loss: 0.0085
# Epoch 34/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0091 - val_loss: 0.0084
# Epoch 35/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0083
# Epoch 36/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0082
# Epoch 37/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0082
# Epoch 38/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0080
# Epoch 39/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0080
# Epoch 40/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 41/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0078
# Epoch 42/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0083 - val_loss: 0.0077
# Epoch 43/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0077
# Epoch 44/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0076
# Epoch 45/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 46/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 47/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0074
# Epoch 48/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097 - val_loss: 0.0073
# Epoch 49/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0072
# Epoch 50/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 51/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0071
# Epoch 52/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0070
# Epoch 53/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 54/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 55/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0068
# Epoch 56/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 57/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0066
# Epoch 58/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 59/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0081 - val_loss: 0.0066
# Epoch 60/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 61/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0087 - val_loss: 0.0063
# Epoch 62/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0075 - val_loss: 0.0062
# Epoch 63/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0080 - val_loss: 0.0062
# Epoch 64/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 65/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0078 - val_loss: 0.0060
# Epoch 66/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 67/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0058
# Epoch 68/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0058
# Epoch 69/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0087 - val_loss: 0.0057
# Epoch 70/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 71/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 72/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0055
# Epoch 73/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 74/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0054
# Epoch 75/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0053
# Epoch 76/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 77/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0051
# Epoch 78/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0051
# Epoch 79/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0050
# Epoch 80/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 81/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 82/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0048
# Epoch 83/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 84/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0046
# Epoch 85/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 86/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0045
# Epoch 87/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 88/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0044
# Epoch 89/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0073 - val_loss: 0.0043
# Epoch 90/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 91/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0042
# Epoch 92/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 93/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 94/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0071 - val_loss: 0.0040
# Epoch 95/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 96/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 97/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 98/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0036
# Epoch 99/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - val_loss: 0.0036
# Epoch 100/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 101/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 102/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0034
# Epoch 103/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0034
# Epoch 104/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0033
# Epoch 105/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 106/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 107/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0032
# Epoch 108/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0031
# Epoch 109/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0030
# Epoch 110/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 111/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0029
# Epoch 112/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0028
# Epoch 113/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 114/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0028
# Epoch 115/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - val_loss: 0.0028
# Epoch 116/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0027
# Epoch 117/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0027
# Epoch 118/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 119/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0026
# Epoch 120/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0025
# Epoch 121/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0025
# Epoch 122/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0025
# Epoch 123/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0059 - val_loss: 0.0025
# Epoch 124/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 125/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0024
# Epoch 126/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0025
# Epoch 127/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0024
# Epoch 128/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0024
# Epoch 129/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0023
# Epoch 130/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0024
# Epoch 131/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0023
# Epoch 132/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0022
# Epoch 133/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0022
# Epoch 134/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 135/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 136/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0022
# Epoch 137/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 138/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0020
# Epoch 139/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - val_loss: 0.0020
# Epoch 140/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 141/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0020
# Epoch 142/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 143/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0019
# Epoch 144/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0019
# Epoch 145/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 146/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 147/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0020
# Epoch 148/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - val_loss: 0.0019
# Epoch 149/420
# 11/11 [==============================] - ETA: 0s - loss: 0.001 - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 150/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 151/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0057 - val_loss: 0.0019
# Epoch 152/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0037 - val_loss: 0.0019
# Epoch 153/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0054 - val_loss: 0.0018
# Epoch 154/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 155/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0018
# Epoch 156/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0039 - val_loss: 0.0018
# Epoch 157/420
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0018
# Epoch 158/420
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0018
# Epoch 159/420
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0035 - val_loss: 0.0018
# Epoch 160/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0061 - val_loss: 0.0018
# Epoch 161/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 162/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0018
# Epoch 163/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0018
# Epoch 164/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0018
# Epoch 165/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0018
# Epoch 166/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 167/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0017
# Epoch 168/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 169/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0019
# Epoch 170/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0019
# Epoch 171/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 172/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 173/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0018
# Epoch 174/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 175/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0017
# Epoch 176/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 177/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 178/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 179/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0057 - val_loss: 0.0017
# Epoch 180/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0017
# Epoch 181/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 182/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 183/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 184/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 185/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 186/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0017
# Epoch 187/420
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 188/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 189/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 190/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 191/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0016
# Epoch 192/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0017
# Epoch 193/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0017
# Epoch 194/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 195/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 196/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 0.0016
# Epoch 197/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0016
# Epoch 198/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 199/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0016
# Epoch 200/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 201/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 202/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 203/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 204/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 205/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 206/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 207/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - val_loss: 0.0016
# Epoch 208/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 209/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0017
# Epoch 210/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0017
# Epoch 211/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0035 - val_loss: 0.0016
# Epoch 212/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 213/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0015
# Epoch 214/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 215/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 216/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0015
# Epoch 217/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 218/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 219/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 220/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0016
# Epoch 221/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 222/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 223/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 224/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 225/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 226/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 227/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 228/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0016
# Epoch 229/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 230/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 231/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0017
# Epoch 232/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 233/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0017
# Epoch 234/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 235/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 236/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 237/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 238/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 239/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 240/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 241/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 242/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 243/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 244/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 245/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 246/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 247/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0016
# Epoch 248/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 249/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 250/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0016
# Epoch 251/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0017
# Epoch 252/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0016
# Epoch 253/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 254/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 255/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0016
# Epoch 256/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0060 - val_loss: 0.0015
# Epoch 257/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0015
# Epoch 258/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 259/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0015
# Epoch 260/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 261/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073 - val_loss: 0.0015
# Epoch 262/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0065 - val_loss: 0.0015
# Epoch 263/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 264/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 265/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 266/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 267/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 268/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 269/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 270/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 271/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 272/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0015
# Epoch 273/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 274/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0015
# Epoch 275/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 276/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0067 - val_loss: 0.0015
# Epoch 277/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 278/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 279/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 280/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 281/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 282/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0056 - val_loss: 0.0014
# Epoch 283/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 284/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 285/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 286/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0016
# Epoch 287/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0015
# Epoch 288/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 289/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 290/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0014
# Epoch 291/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 292/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 293/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 294/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0015
# Epoch 295/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 296/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0044 - val_loss: 0.0016
# Epoch 297/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0016
# Epoch 298/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0016
# Epoch 299/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0042 - val_loss: 0.0015
# Epoch 300/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 301/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0016
# Epoch 302/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 303/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 304/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0015
# Epoch 305/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 306/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 307/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0037 - val_loss: 0.0014
# Epoch 308/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 309/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 310/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 311/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 312/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 313/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 314/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 315/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0015
# Epoch 316/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0015
# Epoch 317/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 318/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 319/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 320/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 321/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0014
# Epoch 322/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0014
# Epoch 323/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 324/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 325/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0016
# Epoch 326/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0015
# Epoch 327/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 328/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0052 - val_loss: 0.0014
# Epoch 329/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 330/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 331/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0014
# Epoch 332/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0065 - val_loss: 0.0014
# Epoch 333/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - val_loss: 0.0014
# Epoch 334/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 335/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 336/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 337/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 338/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - val_loss: 0.0014
# Epoch 339/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0017
# Epoch 340/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 341/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0015
# Epoch 342/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 343/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0015
# Epoch 344/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0039 - val_loss: 0.0014
# Epoch 345/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 346/420
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0014
# Epoch 347/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 348/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 349/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 350/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0053 - val_loss: 0.0014
# Epoch 351/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0049 - val_loss: 0.0015
# Epoch 352/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0037 - val_loss: 0.0015
# Epoch 353/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 354/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 355/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 356/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 357/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - val_loss: 0.0013
# Epoch 358/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 359/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 360/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0059 - val_loss: 0.0013
# Epoch 361/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0014
# Epoch 362/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 363/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 364/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 365/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0013
# Epoch 366/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 367/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 368/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0015
# Epoch 369/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 370/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 371/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 372/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0013
# Epoch 373/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 374/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0014
# Epoch 375/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0036 - val_loss: 0.0014
# Epoch 376/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0014
# Epoch 377/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 378/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0013
# Epoch 379/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 380/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0013
# Epoch 381/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0014
# Epoch 382/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0014
# Epoch 383/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 384/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 385/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 386/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0013
# Epoch 387/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0014
# Epoch 388/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 389/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 390/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0013
# Epoch 391/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 392/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 393/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 394/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 395/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 396/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0014
# Epoch 397/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0014
# Epoch 398/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 399/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0066 - val_loss: 0.0013
# Epoch 400/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0013
# Epoch 401/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0056 - val_loss: 0.0013
# Epoch 402/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 403/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0050 - val_loss: 0.0013
# Epoch 404/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0014
# Epoch 405/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 406/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0013
# Epoch 407/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 408/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0014
# Epoch 409/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 410/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 411/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0045 - val_loss: 0.0013
# Epoch 412/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0014
# Epoch 413/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 414/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0013
# Epoch 415/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 416/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0012
# Epoch 417/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0013
# Epoch 418/420
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0013
# Epoch 419/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0013
# Epoch 420/420
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0013
# Saved model to disk
# Loaded model from disk

# %% [markdown]
# Let's plot the dynamic of loss and val loss like in the previous case.

# %%
plt.figure()
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='test')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend()
plt.show()

# %% [markdown]
# Let's calculate our forecast.

# %%
res_tr_LSTM = model.predict(train_x_LSTM)
res_ts_LSTM = model.predict(test_x_LSTM)
res_train_LSTM=scaler_y.inverse_transform(res_tr_LSTM).flatten()
res_test_LSTM=scaler_y.inverse_transform(res_ts_LSTM).flatten()

# %% [markdown]
# And accuracy:

# %%
print("Correlation train", np.corrcoef(res_train, res_train_LSTM)[0,1])
print("Correlation train", np.corrcoef(res_test, res_test_LSTM)[0,1])
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, res_test_LSTM))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, res_test_LSTM))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, res_test_LSTM)))
# Out:
# Correlation train 0.9952235703533
# Correlation train 0.9832337722167644
# Mean Absolute Error: 46361.042144010986
# Mean Squared Error: 7464534906.180969
# Root Mean Squared Error: 86397.53993130226

# %% [markdown]
# As you can see, the forecast results of the test data set are much better than ones of the previous models. Let's visualize these 3 results:

# %%
res_pred_test_ln = pd.Series(y_pred_test_ln, name = 'Predicted test Linear Model')
res_pred_test_ANN = pd.Series(res_test_ANN, name = 'Predicted test ANN')
res_pred_test_LSTM = pd.Series(res_test_LSTM, name = 'Predicted test LSTM')

df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln, 'ANN Model': res_pred_test_ANN,  'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'Linear Model': res_pred_test_ln,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test, 'LSTM Model': res_pred_test_LSTM,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
df_2 = pd.DataFrame({'Actual test': res_test,'ANN Model': res_pred_test_ANN,})
df_2.index = dataset.index[len(dataset)-len(res_test):]
df_2.plot()
plt.show()

# %% [markdown]
# As you can see, an LSTM model makes a perfect forecast. A Linear Regression is the fastest forecasting model.
